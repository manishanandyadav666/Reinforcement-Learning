# %% [markdown]
# ## Importing required dependencies

# %%
import sys
sys.path.append('/home/dell/miniconda3/lib/python3.8/site-packages')

import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Loading Environment

# %%
environment_name=('CartPole-v0')
env=gym.make(environment_name)

# %%
environment_name
# Out:
# 'CartPole-v0'

# %%
episodes=5
for episode in range(1, episodes+1):
    state=env.reset()
    done=False
    score=0
    
    while not done:
        env.render()
        action=env.action_space.sample()
        n_state, reward, done, info=env.step(action)
        #print(done)
        score+=reward
    print('Episode: {}, Reward: {}'.format(episode, score))
    print(score)
env.close()
# Out:
# Episode: 1, Reward: 32.0
# 32.0
# Episode: 2, Reward: 12.0
# 12.0
# Episode: 3, Reward: 11.0
# 11.0
# Episode: 4, Reward: 18.0
# 18.0
# Episode: 5, Reward: 29.0
# 29.0

# %% [markdown]
# ## Understanding the environment

# %%
env.action_space.sample()
# Out:
# 1

# %%
done
# Out:
# True

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# ## Training

# %%
# Need to make directory first
log_path=os.path.join('Training', 'Logs')
log_path
# Out:
# 'Training/Logs'

# %%
env=gym.make(environment_name)
env=DummyVecEnv([lambda: env])
model=PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 1201 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0093868235 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.00294     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.37         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0202      |
# |    value_loss           | 48.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009984227 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008376794 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009859217 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 62.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006731784 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 63.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 7            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0042615943 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 60.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 798          |
# |    iterations           | 8            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0029618014 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.511        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 74.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 9            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0034866314 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.28         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 47           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 783          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0032878015 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.277        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00631     |
# |    value_loss           | 113          |
# ------------------------------------------

# %% [markdown]
# ## Save and Reload model

# %%
PPO_path=os.path.join('Training','Saved Models', 'ppo_model_cartpole')

# %%
model.save(PPO_path)

# %% [markdown]
# ## Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# ## Test

# %%
episodes=5
for episode in range(1, episodes+1):
    obs=env.reset()
    done=False
    score=0
    
    while not done:
        env.render()
        action, _=model.predict(obs)
        obs, reward, done, info=env.step(action)
        #print(done)
        score+=reward
    print('Episode: {}, Reward: {}'.format(episode, score))
    print(score)
env.close()
# Out:
# Episode: 1, Reward: [192.]
# [192.]
# Episode: 2, Reward: [200.]
# [200.]
# Episode: 3, Reward: [200.]
# [200.]
# Episode: 4, Reward: [200.]
# [200.]
# Episode: 5, Reward: [200.]
# [200.]

# %% [markdown]
# ### Unfolding things

# %%
obs=env.reset()

# %%
obs
# Out:
# array([[0.01306982, 0.03553905, 0.00657437, 0.02909288]], dtype=float32)

# %%
action, _=model.predict(obs)

# %%
action
# Out:
# array([1])

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.step(action)
# Out:
# (array([[ 0.0137806 ,  0.2305661 ,  0.00715622, -0.26150852]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{}])

# %% [markdown]
# ### Viewing logs in tensorboard

# %%
training_log_path=os.path.join(log_path, 'PPO_3')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_3'

# %% [markdown]
# ## Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path=os.path.join('Training','Saved Models')

# %%
stop_callback=StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback=EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, best_model_save_path=save_path,
                          verbose=1)

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 1433 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009754866 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 60.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 881        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00748992 |
# |    clip_fraction        | 0.0842     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.583     |
# |    explained_variance   | 0.428      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.8       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 75.1       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0034792798 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.6         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 86.4         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007946323 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 81.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 788   |
# |    iterations      | 5     |
# |    time_elapsed    | 12    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067372858 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 88.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003402269 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 109         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0028585372 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.0524       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 152          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 9            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0048941197 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.0378       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 149          |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0035521216 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 743   |
# |    iterations      | 10    |
# |    time_elapsed    | 27    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## Changing Policies

# %%
net_arch=[dict(pi=[128,128,128,128],vf=[128,128,128,128])]

# %%
model=PPO('MlpPolicy',env, verbose=1, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 944  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013080381 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 17.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016511824 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 24.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012966743 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 47.4        |
# -----------------------------------------
# Eval num_timesteps=9520, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 9520        |
# | train/                  |             |
# |    approx_kl            | 0.009169128 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 51.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 518   |
# |    iterations      | 5     |
# |    time_elapsed    | 19    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 6            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0060718697 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.46         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 45.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004215774 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00082    |
# |    value_loss           | 78.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005227755 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 75.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005426338 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 53.4        |
# -----------------------------------------
# Eval num_timesteps=19520, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 200        |
# |    mean_reward          | 200        |
# | time/                   |            |
# |    total timesteps      | 19520      |
# | train/                  |            |
# |    approx_kl            | 0.00488983 |
# |    clip_fraction        | 0.0318     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.53      |
# |    explained_variance   | 0.516      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.3       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00248   |
# |    value_loss           | 86.4       |
# ----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 387   |
# |    iterations      | 10    |
# |    time_elapsed    | 52    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## Using an alternative algorithm

# %%
from stable_baselines3 import DQN
model=DQN('MlpPolicy',env, verbose=1, tensorboard_log=log_path )
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, )
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.927    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4171     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.881    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4771     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.837    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5189     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 344      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.786    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5127     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.729    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4759     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 571      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.675    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4934     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 685      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.645    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4855     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 747      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.608    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4801     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 826      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.575    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4765     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.54     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4601     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 968      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.482    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4717     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.434    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4819     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.387    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4818     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.356    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4805     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.284    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4913     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.24     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4907     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.207    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4888     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.176    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4934     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.131    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5011     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0799   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5015     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5071     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5052     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5111     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5092     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5089     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5151     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5231     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5239     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5272     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5299     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5309     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5282     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 5283     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5269     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 5261     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5231     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 5234     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 5225     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5230     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5232     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5261     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5254     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5289     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5266     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3959     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5269     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5274     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5293     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5314     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5332     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5315     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5304     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5295     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5298     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5270     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5308     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4957     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5305     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5305     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5309     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5314     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5325     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5346     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5363     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5368     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5381     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5425     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5431     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5444     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5461     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5468     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5460     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5473     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5454     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5456     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5466     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5465     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5426     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5383     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5387     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5391     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5400     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5410     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5416     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5430     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5431     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5414     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5419     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5439     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5442     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5445     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5453     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5458     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5453     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5455     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5457     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5445     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5442     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5460     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5458     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5460     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5479     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5479     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5488     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5501     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5521     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5525     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5515     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5519     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5472     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5433     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5422     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5410     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5429     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5193     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5194     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5206     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5214     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5216     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5223     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5235     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5241     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5240     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5238     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5254     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5256     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5262     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5275     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5287     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 5292     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 5303     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 5294     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 5288     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 5290     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 5284     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 5288     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 11928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 5289     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 5303     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 5303     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 5315     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 5319     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 5328     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 5340     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 5339     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 5340     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 5342     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 5348     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 5356     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 12949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 5358     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 5370     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 5370     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 5361     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 5363     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 5367     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 13547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 5417     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 5420     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 5425     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 5427     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 5427     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 5429     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 5435     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 5439     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 5444     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 5449     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 5454     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 5458     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 5452     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 5460     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 5467     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 5469     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 16988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 5465     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 5459     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 5455     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 5448     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 5439     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 5434     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 5434     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 5427     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 5425     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 5418     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 5412     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 5415     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 17929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 5415     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 5415     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 5420     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 5421     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 5417     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 5420     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 5418     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 5415     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 5413     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 5421     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 5424     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 5422     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 5421     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 18958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 5423     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 5423     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 5421     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 5420     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 5437     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 5444     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 5444     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 5448     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 5446     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 5450     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 19985    |
# ----------------------------------
